# %%
import torch

# %%
torch.bmm()

# %%
W = torch.randn(2, 3, 4)
X = torch.randn(2, 4, 5)

# %%
# Out:
# tensor([[[ 0.6529, -2.3431,  0.9285,  1.4584, -0.0289],
#          [ 1.9680,  0.0560, -3.3084,  4.2775, -0.8856],
#          [ 1.0149, -1.8755,  2.6023, -2.3752,  3.8247]],
#
#         [[-0.9291, -1.3054, -0.0061,  0.2641, -1.5141],
#          [-0.4565, -0.5418,  0.3689, -0.8404,  2.3013],
#          [ 2.5028,  0.1808, -0.7829, -2.4861,  5.0182]]])
